# %%
# importing pandas as pd 
import pandas as pd

# %%
#assigning the filepaths to a variable
file_country = 'Edstats_csv/EdStatsCountry.csv'

# %%
df = pd.read_csv(file_country)
df.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
df_country_name_with_features = df.loc[:,['Short Name','Income Group', 'Latest population census']]
df_country_name_with_features
# Out:
#                          Short Name          Income Group  \
# 0                             Aruba  High income: nonOECD
# 1                       Afghanistan            Low income
# 2                            Angola   Upper middle income
# 3                           Albania   Upper middle income
# 4                           Andorra  High income: nonOECD
# 5                        Arab World                   NaN
# 6              United Arab Emirates  High income: nonOECD
# 7                         Argentina   Upper middle income
# 8                           Armenia   Lower middle income
# 9                    American Samoa   Upper middle income
# 10              Antigua and Barbuda  High income: nonOECD
# 11                        Australia     High income: OECD
# 12                          Austria     High income: OECD
# 13                       Azerbaijan   Upper middle income
# 14                          Burundi            Low income
# ...

# %%
df_country_name_with_features['Income Group'].value_counts()
# Out:
# Upper middle income     55
# Lower middle income     50
# High income: nonOECD    44
# Low income              34
# High income: OECD       31
# Name: Income Group, dtype: int64

# %%
df_country_name_with_features['Latest population census'].value_counts()
# Out:
# 2011                                                                                                                                                                              59
# 2010                                                                                                                                                                              49
# 2012                                                                                                                                                                              18
# 2009                                                                                                                                                                              14
# 2007                                                                                                                                                                               9
# ...
